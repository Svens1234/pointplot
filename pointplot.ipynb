# %%
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.pointplot(x="time", y="total_bill", data=tips)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                   data=tips)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                   data=tips, dodge=True)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                   data=tips, dodge=False)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                   data=tips,
                   markers=["o", "x"],
                   linestyles=["-", "--"])
# Out:
# c:\python\python38\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.8666666666666667, 0.5176470588235295, 0.3215686274509804)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
ax = sns.pointplot(x="tip", y="day", data=tips)

# %%
ax = sns.pointplot(x="tip", y="day", data=tips, join=False)

# %%
ax = sns.pointplot(x="tip", y="day", data=tips, join=True)

# %%
ax = sns.pointplot(x="time", y="total_bill", data=tips,
                   color="#bb3f3f")

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                   data=tips, palette="Set2")

# %%
ax = sns.pointplot(x="time", y="tip", data=tips,
                   order=["Dinner", "Lunch"])
